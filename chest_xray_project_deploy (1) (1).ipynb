# %%
from google.colab import files
uploaded = files.upload()
# Upload these 4 files when prompted:
# app.py, requirements.txt, covid19_pneumonia_knowledge.txt, your .keras model file
# Out:
#      <input type="file" id="files-20c9436d-c185-4c7d-9fd5-891e9ac9b036" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-20c9436d-c185-4c7d-9fd5-891e9ac9b036">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import os

# Create required folders
os.makedirs('rag_docs', exist_ok=True)
os.makedirs('.streamlit', exist_ok=True)

# Move knowledge base file into rag_docs/
if os.path.exists('covid19_pneumonia_knowledge.txt'):
    os.rename('covid19_pneumonia_knowledge.txt', 'rag_docs/covid19_pneumonia_knowledge.txt')

# Check what your model file is actually named
print("Files in current folder:")
print(os.listdir('.'))
# Out:
# Files in current folder:
# ['.config', 'chest_xray_covid_detector (1).keras', '.streamlit', 'requirements.txt', 'secrets.toml', 'app.py', 'rag_docs', 'sample_data']

# %%
# Look at the Cell 2 output above. Find your .keras file name.
# If it has extra characters like "(1)" or spaces, rename it exactly like this:

import os
for f in os.listdir('.'):
    if f.endswith('.keras'):
        os.rename(f, 'chest_xray_covid_detector.keras')
        print(f"Renamed '{f}' to 'chest_xray_covid_detector.keras'")
        break

print(os.listdir('.'))  # confirm
# Out:
# Renamed 'chest_xray_covid_detector (1).keras' to 'chest_xray_covid_detector.keras'
# ['.config', '.streamlit', 'requirements.txt', 'chest_xray_covid_detector.keras', 'secrets.toml', 'app.py', 'rag_docs', 'sample_data']

# %%
secrets = '''
GROQ_API_KEY = "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"
'''

with open('.streamlit/secrets.toml', 'w') as f:
    f.write(secrets)

print("Secrets file created.")
# Out:
# Secrets file created.

# %%
# !pip install streamlit groq opencv-python-headless numpy pyngrok -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.2/9.2 MB 51.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.7/143.7 kB 4.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 94.9 MB/s eta 0:00:00

# %%
from pyngrok import ngrok
import subprocess
import time

# Kill any old processes/tunnels
try:
    subprocess.run(['fuser', '-k', '8501/tcp'], check=False, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
except Exception:
    pass

ngrok.kill()
time.sleep(1)

# Use a NEW ngrok token (your old one was exposed earlier in this chat)
ngrok.set_auth_token("3FCfAhJ0L9O3Czkh4jpBa8Pef4i_27Av1fqf7uA7jB3GARwQo")

# %%
import threading
import os
import time

threading.Thread(
    target=lambda: os.system('streamlit run app.py --server.port 8501')
).start()

time.sleep(10)

public_url = ngrok.connect(8501)
print("🎉 Your app is live at:", public_url)
# Out:
# 🎉 Your app is live at: NgrokTunnel: "https://unimpeded-unplug-among.ngrok-free.dev" -> "http://localhost:8501"
